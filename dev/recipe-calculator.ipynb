# %% [markdown]
# # recipe calculator

# %% [markdown]
# Development work on creating a python program to calculate food cost and nutritional information per serving for a provided recipe (url or manual).
#
# Resources used:
# - https://hackersandslackers.com/scraping-urls-with-beautifulsoup/

# %% [markdown]
# ## import packages

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import os
import re

# %% [markdown]
# ## scrape website for recipe

# %% [markdown]
# URL with recipe for testing: https://www.theleangreenbean.com/white-bean-bars/

# %%
# spoofing headers to avoid website knowing it's a scraper (don't think this will be necessary for public recipe urls)

headers = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'
    }

# %%
url = "https://www.theleangreenbean.com/white-bean-bars/"
req = requests.get(url, headers)
soup = BeautifulSoup(req.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Sweet Potato White Bean Bars
#   </title>
#   <!-- This site is optimized with the Yoast SEO plugin v12.5 - https://yoast.com/wordpress/plugins/seo/ -->
#   <meta content="These Sweet Potato White Bean Bars are perfect for breakfast or snack time. They're kid-friendly, nut-free and full of fiber! " name="description"/>
#   <meta content="max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
#   <link href="https://www.theleangreenbean.com/white-bean-bars/" rel="canonical"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="article" property="og:type"/>
#   <meta content="Sweet Potato White Bean Bars" property="og:title"/>
# ...

# %%
soup.find_all(attrs={"data-args": "ingredients"})
# Out:
# []

# %%
soup.find_all(class_="p")
# Out:
# []

# %%
for ing in soup.select('div[class*="span data-amount"]'):
    print(ing.get_text())

# %%
regex = re.compile('.*recipeIngredient.*')
for EachPart in soup.find_all("div", {"class" : regex}):
        print(EachPart.get_text())
